# %%
import pandas as pd
import numpy as np

# %%
lc = pd.read_csv("../data/photometry/photall.txt", sep='\t')

# %%
np.unique(lc["instrument"].values)
# Out:
# array(['LT+IOO', 'P48', 'P60+SEDM', 'Swift'], dtype=object)

# %%
    # 1. LT
    ix1 = lc["instrument"].values=='LT+IOO'
    lc1 = lc[ix1]
    mjds = lc1['mjd'].values
    mags = lc1['mag'].values
    emags = lc1['emag'].values
    filters = lc1['filter'].values
    for i in range(len(lc1)):
        print ('%.4f'%mjds[i], '&', 'LT$+$IOO', '&', '$'+filters[i]+'$', '&', '%.2f'%mags[i], '&', '%.2f'%emags[i], '\\\\')
    
    # 2. ZTF+P48
    ix2 = lc["instrument"].values=='P48'
    lc2 = lc[ix2]
    mjds = lc2['mjd'].values
    mags = lc2['mag'].values
    emags = lc2['emag'].values
    filters = lc2['filter'].values
    for i in range(len(mags)):
        if mags[i]!=0:
            print ('%.4f'%mjds[i], '&', 'P48$+$ZTF', '&', '$'+filters[i]+'$', '&', '%.2f'%mags[i], '&', '%.2f'%emags[i], '\\\\')
    
    # 3. UVOT
    ix3 = lc["instrument"].values=='Swift'
    lc3 = lc[ix3]
    mjds = lc3['mjd'].values
    mags = lc3['mag'].values
    emags = lc3['emag'].values
    filters = lc3['filter'].values
    for i in range(len(mjds)):
        print ('%.4f'%mjds[i], '&', '$Swift+$UVOT', '&', '$'+filters[i]+'$', '&', '%.2f'%mags[i], '&', '%.2f'%emags[i], '\\\\')
# Out:
# 58582.1544 & LT$+$IOO & $g$ & 18.59 & 0.01 \\
# 58582.1552 & LT$+$IOO & $r$ & 18.84 & 0.02 \\
# 58582.1575 & LT$+$IOO & $i$ & 19.11 & 0.02 \\
# 58582.1583 & LT$+$IOO & $z$ & 19.28 & 0.07 \\
# 58583.1637 & LT$+$IOO & $g$ & 18.48 & 0.02 \\
# 58583.1645 & LT$+$IOO & $r$ & 18.63 & 0.01 \\
# 58584.2324 & LT$+$IOO & $g$ & 18.58 & 0.01 \\
# 58584.2332 & LT$+$IOO & $r$ & 18.68 & 0.02 \\
# 58584.2355 & LT$+$IOO & $i$ & 18.85 & 0.02 \\
# 58584.2363 & LT$+$IOO & $z$ & 19.15 & 0.07 \\
# 58590.0252 & LT$+$IOO & $g$ & 19.47 & 0.14 \\
# 58590.0260 & LT$+$IOO & $r$ & 19.16 & 0.04 \\
# 58590.0268 & LT$+$IOO & $i$ & 19.24 & 0.07 \\
# 58590.0277 & LT$+$IOO & $z$ & 19.28 & 0.21 \\
# 58591.0676 & LT$+$IOO & $g$ & 19.44 & 0.07 \\
# 58591.0685 & LT$+$IOO & $r$ & 19.31 & 0.09 \\
# 58591.0693 & LT$+$IOO & $i$ & 19.22 & 0.06 \\
# 58591.0701 & LT$+$IOO & $z$ & 19.10 & 0.12 \\
# 58592.0472 & LT$+$IOO & $g$ & 19.40 & 0.13 \\
# 58592.0472 & LT$+$IOO & $r$ & 19.26 & 0.12 \\
# ...

# %% [markdown]
# ### Print out blackbody parameters

# %%
tb = pd.read_csv('../data/otherSN/Yao2020/bbdata.csv')
tb.head()
# Out:
#       phase           Lbb       Lbb_unc      Lbb_uncr      Lbb_uncl  \
# 0 -2.736850  1.776879e+41  0.000000e+00  0.000000e+00  0.000000e+00
# 1 -1.724067  4.582789e+42  3.292607e+42  4.911296e+42  1.673918e+42
# 2 -0.658517  2.716659e+42  1.105217e+41  1.132114e+41  1.078319e+41
# 3  0.267700  1.926464e+42  7.455119e+40  7.635395e+40  7.274844e+40
# 4  1.101233  1.572078e+42  4.401672e+40  4.566036e+40  4.237307e+40
#
#        lgLbb  lgLbb_unc  lgLbb_uncr  lgLbb_uncl           Tbb      Tbb_unc  \
# 0  41.249658   0.000000    0.000000    0.000000  10083.024509     0.000000
# 1  42.661130   0.256864    0.316323    0.197405  23013.427918  6262.748948
# 2  42.434035   0.017661    0.017731    0.017590  15969.351486   336.913072
# 3  42.284761   0.016799    0.016881    0.016718  12322.732023   288.674329
# 4  42.196474   0.012150    0.012434    0.011866  11195.698717   222.691129
#
#       Tbb_uncr     Tbb_uncl          Rbb     Rbb_unc    Rbb_uncr    Rbb_uncl
# ...

# %%
for i in range(len(tb)):
    phase = tb["phase"].values[i]
    s1= "%.2f"%phase + ' & '
    Lbb = tb["Lbb"].values[i]
    Lbb_uncr = tb["Lbb_uncr"].values[i]
    Lbb_uncl = tb["Lbb_uncl"].values[i]
    Tbb = tb["Tbb"].values[i]
    Tbb_uncr = tb["Tbb_uncr"].values[i]
    Tbb_uncl = tb["Tbb_uncl"].values[i]
    Rbb = tb["Rbb"].values[i]
    Rbb_uncr = tb["Rbb_uncr"].values[i]
    Rbb_uncl = tb["Rbb_uncl"].values[i]
    
    if Lbb_uncr!=0:
        s2 = '$'+"%.2f"%(Lbb/1e+41) + "^{+" + "%.2f"%(Lbb_uncr/1e+41) + "}_{-"+ "%.2f"%(Lbb_uncl/1e+41) + "}$ &"
        s3 = '$'+"%.2f"%(Rbb/1e+3) + "^{+" + "%.2f"%(Rbb_uncr/1e+3) + "}_{-"+ "%.2f"%(Rbb_uncl/1e+3) + "}$ &"
        s4 = '$'+"%.2f"%(Tbb/1e+3) + "^{+" + "%.2f"%(Tbb_uncr/1e+3) + "}_{-"+ "%.2f"%(Tbb_uncl/1e+3) + "}$  \\\\"
    else:
        s2 = '$'+"%.2f"%(Lbb/1e+41) + "$ & "
        s3 = '$'+"%.2f"%(Rbb/1e+3) + "$ & "
        s4 = '$'+"%.2f"%(Tbb/1e+3) + "$  \\\\"
    print (s1 + s2 + s3 + s4)
# Out:
# -2.74 & $1.78$ & $2.23$ & $10.08$  \\
# -1.72 & $45.83^{+49.11}_{-16.74}$ &$2.18^{+0.45}_{-0.48}$ &$23.01^{+8.21}_{-4.31}$  \\
# -0.66 & $27.17^{+1.13}_{-1.08}$ &$3.48^{+0.08}_{-0.08}$ &$15.97^{+0.34}_{-0.33}$  \\
# 0.27 & $19.26^{+0.76}_{-0.73}$ &$4.92^{+0.14}_{-0.14}$ &$12.32^{+0.29}_{-0.29}$  \\
# 1.10 & $15.72^{+0.46}_{-0.42}$ &$5.39^{+0.14}_{-0.14}$ &$11.20^{+0.23}_{-0.22}$  \\
# 3.26 & $8.34^{+0.22}_{-0.20}$ &$7.27^{+0.46}_{-0.44}$ &$8.22^{+0.31}_{-0.28}$  \\
# 4.24 & $7.25$ & $7.37$ & $7.89$  \\
# 5.25 & $6.09$ & $8.81$ & $6.90$  \\
# 6.83 & $6.16^{+0.63}_{-0.45}$ &$7.12^{+1.02}_{-0.92}$ &$7.70^{+0.74}_{-0.62}$  \\
# 7.98 & $5.28^{+0.23}_{-0.21}$ &$8.02^{+0.76}_{-0.70}$ &$6.98^{+0.39}_{-0.35}$  \\
# 8.98 & $5.48^{+0.43}_{-0.35}$ &$6.86^{+0.95}_{-0.87}$ &$7.61^{+0.65}_{-0.55}$  \\
# 10.05 & $4.53^{+0.35}_{-0.26}$ &$7.49^{+1.04}_{-0.95}$ &$6.95^{+0.61}_{-0.51}$  \\
# 10.92 & $4.47^{+0.64}_{-0.44}$ &$6.70^{+1.24}_{-1.09}$ &$7.32^{+0.93}_{-0.74}$  \\
# ...
